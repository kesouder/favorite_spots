# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ### Favorite Spots (draft)
# - La jolla shores
#     - will be main gift --> need to print out
# - Dennys
# - Mt Soledad
# - Target
# - In N Out
# - Canyon Park
# - Renaissance
# - Our first hike --> need to find what it was called
# -

# %%
pins = {
    "favorite_spots": [
        {
            "name": "La Jolla Shores",
            "latitude": 32.858119,
            "longitude": -117.256714,
            "description": "Where we had our first hang out, and where we had our first kiss!"
        },
        {
            "name": "Mt Soledad",
            "latitude": 32.839711,
            "longitude": -117.246893,
            "description": "Where we had our first emotional talk. <3"
        },
        {
            "name": "La Jolla Blue",
            "latitude": 32.862639,
            "longitude": -117.229001,
            "description": "ikyky ;)"
        },
        {
            "name": "Target - Clairemont",
            "latitude": 32.821710,
            "longitude": -117.178502,
            "description": "Pinkity Drinkity and Shopping at Target."
        },
        {
            "name": "That Hike",
            "latitude": 32.979756,
            "longitude": -117.270162,
            "description": "Pink gymshark fit and hiking with my favorite person ever. \n Feb 24 2024"
        },
        {
            "name": "Annie's Canyon",
            "latitude": 33.004814,
            "longitude": -117.263834,
            "description": "Instagram Hike that we finally got to do!"
        },
        {
            "name": "YT House",
            "latitude": 32.806288,
            "longitude": -117.186303,
            "description": "Frat Wedding!!!"
        },
        {
            "name": "Kate Sessions",
            "latitude": 32.811293,
            "longitude": -117.237063,
            "description": "Our favorite Picnic Spot!!"
        },
        {
            "name": "In N Out",
            "latitude": 32.808851,
            "longitude": -117.218720,
            "description": "In N Out \n Cheesburger animal style, fries, animal style, pink lemonade."
        },
        {
            "name": "Canyon Park Apartments",
            "latitude": 32.880917,
            "longitude": -117.216590,
            "description": "Gotta shout of Canyon Park and all the meals we cooked here together. <3 (mainly you)"
        },
        {
            "name": "Dennys",
            "latitude": 32.832427,
            "longitude":  -117.201849,
            "description": "Where we shared our first meal together. :) Berry Stuffed French Toast\n Shoutout the time you took me here after an open."
        },
        {
            "name": "Ototo Sushi",
            "latitude": 32.818832,
            "longitude": -117.178827,
            "description": "I think this is our go to sushi spot now."
        },
        {
            "name": "Geisel Library",
            "latitude":32.880799,
            "longitude": -117.237564,
            "description": "A time spent here, both productive and unproductive, but time spent together is always worth it. \n RIP my goldfish extra cheddar"
        }
        
    ]
}

# %%
with open('locations.json', 'w') as f:
    json.dump(pins, f, indent=2)
